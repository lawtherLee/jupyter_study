# %% [markdown]
# ## 常用属性

# %%
import numpy as np

# %%
arr = np.arange(15).reshape(3,5)
print(arr)

# %%
print(f'数组的维度:{arr.ndim}')
print(f'数组的形状:{arr.shape}')
print(f'数组的元素类型:{arr.dtype}')
print(f'数组的每个元素占的字节数:{arr.itemsize}')
print(f'数组的元素个数:{arr.size}')
